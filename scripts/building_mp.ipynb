# %%
# Add Code Directory (TEMPORY FIX)
import sys
sys.path.append('/home/jhrag/Code')

# %%
import numpy as np
import scipy
from matplotlib import pyplot as plt
from NI_simulation.modules import ni_sim
from scipy import interpolate
import multiprocessing as mp

# %load_ext autoreload
# %autoreload 2

# %%
sources = ni_sim.source_distribution2D().uniform_circular(10000, [0,0], 10)
env = ni_sim.environment(sources)
fig, _ = env.plot_env()

# %%
xA, xB = env.get_signals()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-a183ac8aebb9> in <module>
# ----> 1 xA, xB = env.get_signals()
#
# ~/Code/NI_simulation/modules/ni_sim.py in get_signals(self)
#     134         # Divide dataframe up into num_processes chunks
#     135         #chunks = [sources.ix[sources.index[i:i + chunk_size]] for i in range(0, sources.shape[0],chunk_size)]
# --> 136         chunks = [sources.iloc[i:i + chunk_size,:] for i in range(0, sources.shape[0], chunk_size)]
#     137
#     138         # TQDM
#
# ValueError: range() arg 3 must not be zero

# %%
plt.plot(xA)
